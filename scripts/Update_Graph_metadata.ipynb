# %% [markdown]
# ## Import data & add new metadata

# %%
from pathlib import Path
home = Path.home()
file_dir = home / "balzac_project"/ "balzac_project" / "data"

# %%
import pandas as pd
import os
from collections import Counter

os.chdir(file_dir)

nodes_df = pd.read_csv('nodes_vs_export.csv')
nodes = [{'data': row.to_dict()} for _, row in nodes_df.iterrows()]
net_df = pd.read_csv('character_frequencies.csv')
metadata_df = pd.read_csv('character_metadata.csv')

# %%
# merge new metadata into nodes_df

metadata_df = metadata_df.rename(columns={"Character": "id"})
nodes_df = nodes_df.reset_index()
metadata_df = metadata_df.reset_index()
nodes_df = nodes_df.merge(metadata_df, on="id", how="left")

# %%
nodes_df.drop(columns=['Name Variants', 'index_y', 'Major Appearances', 'Minor Appearances', 'index_x'], inplace=True)

# %%
nodes_df['Social Class'] = nodes_df['Social Class'].str.strip()
nodes_df['Gender'] = nodes_df['Gender'].str.strip()

# %%
nodes_df
# Out:
#                                     id                              label  \
# 0                        Andoche Finot                      Andoche Finot
# 1                  A PRINCE OF BOHEMIA                A PRINCE OF BOHEMIA
# 2                  THE DEPUTY OF ARCIS                THE DEPUTY OF ARCIS
# 3                    A DAUGHTER OF EVE                  A DAUGHTER OF EVE
# 4                               URSULA                             URSULA
# ..                                 ...                                ...
# 105                      Madame Roguin                      Madame Roguin
# 106                           VENDETTA                           VENDETTA
# 107  AT THE SIGN OF THE CAT AND RACKET  AT THE SIGN OF THE CAT AND RACKET
# 108            Vicomtesse de Beauséant            Vicomtesse de Beauséant
# 109                 THE DESERTED WOMAN                 THE DESERTED WOMAN
#
#           type       color   shape  size                        scene  Gender  \
# 0    character     skyblue     dot    25                          NaN    male
# 1        novel     #FF6F61  square    40  SCENES DE LA VIE PARISIENNE     NaN
# 2        novel   goldenrod  square    50   SCENES DE LA VIE POLITIQUE     NaN
# 3        novel        blue  square    50      SCENES DE LA VIE PRIVEE     NaN
# 4        novel  sandybrown  square    40    SCENES DE LA VIE PROVINCE     NaN
# ..         ...         ...     ...   ...                          ...     ...
# 105  character     skyblue     dot    10                          NaN  female
# 106      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
# 107      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
# 108  character     skyblue     dot    20                          NaN  female
# 109      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
#
#         Social Class                              Character Description
# 0        Bourgeoisie  Newspaper editor and businessman\nSon of a hat...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# ..               ...                                                ...
# 105      Bourgeoisie  Wealthy provinical bourgeouisie \nWife of Rogu...
# 106              NaN                                                NaN
# 107              NaN                                                NaN
# 108  Old Aristocracy  Cousin of Rastignac\nEventually Comtesse, then...
# 109              NaN                                                NaN
#
# [110 rows x 10 columns]

# %% [markdown]
# ## Update graph HTML with beautiful soup

# %%
nodes_df
# Out:
#                                                                label  \
# id
# Andoche Finot                                          Andoche Finot
# A PRINCE OF BOHEMIA                              A PRINCE OF BOHEMIA
# THE DEPUTY OF ARCIS                              THE DEPUTY OF ARCIS
# A DAUGHTER OF EVE                                  A DAUGHTER OF EVE
# URSULA                                                        URSULA
# ...                                                              ...
# Madame Roguin                                          Madame Roguin
# VENDETTA                                                    VENDETTA
# AT THE SIGN OF THE CAT AND RACKET  AT THE SIGN OF THE CAT AND RACKET
# Vicomtesse de Beauséant                      Vicomtesse de Beauséant
# THE DESERTED WOMAN                                THE DESERTED WOMAN
#
#                                         type       color   shape  size  \
# id
# Andoche Finot                      character     skyblue     dot    25
# A PRINCE OF BOHEMIA                    novel     #FF6F61  square    40
# THE DEPUTY OF ARCIS                    novel   goldenrod  square    50
# A DAUGHTER OF EVE                      novel        blue  square    50
# URSULA                                 novel  sandybrown  square    40
# ...                                      ...         ...     ...   ...
# Madame Roguin                      character     skyblue     dot    10
# VENDETTA                               novel        blue  square    10
# AT THE SIGN OF THE CAT AND RACKET      novel        blue  square    10
# Vicomtesse de Beauséant            character     skyblue     dot    20
# THE DESERTED WOMAN                     novel        blue  square    10
#
#                                                          scene  gender  \
# id
# Andoche Finot                                              NaN    male
# A PRINCE OF BOHEMIA                SCENES DE LA VIE PARISIENNE     NaN
# THE DEPUTY OF ARCIS                 SCENES DE LA VIE POLITIQUE     NaN
# A DAUGHTER OF EVE                      SCENES DE LA VIE PRIVEE     NaN
# URSULA                               SCENES DE LA VIE PROVINCE     NaN
# ...                                                        ...     ...
# Madame Roguin                                              NaN  female
# VENDETTA                               SCENES DE LA VIE PRIVEE     NaN
# AT THE SIGN OF THE CAT AND RACKET      SCENES DE LA VIE PRIVEE     NaN
# Vicomtesse de Beauséant                                    NaN  female
# THE DESERTED WOMAN                     SCENES DE LA VIE PRIVEE     NaN
#
#                                       social_class  \
# id
# Andoche Finot                          Bourgeoisie
# A PRINCE OF BOHEMIA                            NaN
# THE DEPUTY OF ARCIS                            NaN
# A DAUGHTER OF EVE                              NaN
# URSULA                                         NaN
# ...                                            ...
# Madame Roguin                          Bourgeoisie
# VENDETTA                                       NaN
# AT THE SIGN OF THE CAT AND RACKET              NaN
# Vicomtesse de Beauséant            Old Aristocracy
# THE DESERTED WOMAN                             NaN
#
#                                                                                title
# id
# Andoche Finot                      Newspaper editor and businessman\nSon of a hat...
# A PRINCE OF BOHEMIA                                                              NaN
# THE DEPUTY OF ARCIS                                                              NaN
# A DAUGHTER OF EVE                                                                NaN
# URSULA                                                                           NaN
# ...                                                                              ...
# Madame Roguin                      Wealthy provinical bourgeouisie \nWife of Rogu...
# VENDETTA                                                                         NaN
# AT THE SIGN OF THE CAT AND RACKET                                                NaN
# Vicomtesse de Beauséant            Cousin of Rastignac\nEventually Comtesse, then...
# THE DESERTED WOMAN                                                               NaN
#
# [110 rows x 9 columns]

# %%
graph_dir = home / "balzac_project" / "balzac_project" 
os.chdir(graph_dir)

# %%
nodes_df = pd.read_csv("updated_nodes.csv", quotechar='"', engine='python')

# %%
nodes_df.set_index("id", inplace=True)

# %%
from bs4 import BeautifulSoup
# open HTML file
with open("balzac_character_network_with_filters.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

script_tag = None
for s in soup.find_all("script"):
    if "nodes = new vis.DataSet" in s.text:
        script_tag = s
        break

script_text = script_tag.string

# %%
import regex as re
import json

# search for nodes
pattern = r"new vis\.DataSet\(\s*(\[\{.*?\}\])\s*\)"
match = re.search(pattern, script_text, re.DOTALL)
if match:
    nodes_json_str = match.group(1)
    nodes_json_str = nodes_json_str.replace("NaN", "null").replace("undefined", "null") # replace NaN with null
    nodes_list = json.loads(nodes_json_str)
else:
    raise ValueError("Could not find vis.DataSet array")


# add new metadata
for node in nodes_list:
    node_id = node['id']
    if node_id in nodes_df.index:
        gender = nodes_df.at[node_id, 'gender']
        social_class = nodes_df.at[node_id, 'social_class']
        title = nodes_df.at[node_id, 'title']
        node['title'] = None if pd.isna(title) else title
        node['gender'] = None if pd.isna(gender) else gender
        node['social_class'] = None if pd.isna(social_class) else social_class
    
    else:
        node['gender'] = None
        node['social_class'] = None
        node['title'] = None

    for k, v in node.items(): 
        if pd.isna(v):
            node[k] = None

# %%
def fix_line_breaks(s):
    if not s or pd.isna(s):
        return None
    s = str(s)  # ensure it's a string
    s = s.replace("\\", "\\\\")  # escape backslashes first
    s = s.replace('"', '\\"')    # escape quotes
    s = s.replace("\n", "\\n")   # escape newlines
    return s

for node in nodes_list:
    node['title'] = fix_line_breaks(node.get('title'))

# %%
nodes_json_str = json.dumps(nodes_list, ensure_ascii=False)

# replace the original nodes
updated_script_text = re.sub(
    pattern,
    f"nodes = new vis.DataSet({nodes_json_str});",
    script_text,
    flags=re.DOTALL
)

# update the script tag 
script_tag.string.replace_with(updated_script_text)

# write new file
with open("balzac_character_network_test.html", "w", encoding="utf-8") as f:
    f.write(str(soup))

# %%
nodes_list
# Out:
# [{'color': '#5a7684',
#   'id': 'Andoche Finot',
#   'label': 'Andoche Finot',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Newspaper editor and businessman\\\\\\\\nSon of a hatter\\\\\\\\nEventually ascends to newspaper owner and a commerical force\\\\\\\\nUsually features with journalists or financiers (Gaudissart, des Lupeaulx)',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': ' #1a1a40',
#   'id': 'A PRINCE OF BOHEMIA',
#   'label': 'A PRINCE OF BOHEMIA',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#631d1d',
#   'id': 'THE DEPUTY OF ARCIS',
#   'label': 'THE DEPUTY OF ARCIS',
#   'scene': 'SCENES DE LA VIE POLITIQUE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'A DAUGHTER OF EVE',
#   'label': 'A DAUGHTER OF EVE',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'URSULA',
#   'label': 'URSULA',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'SCENES FROM A COURTESANS LIFE',
#   'label': 'SCENES FROM A COURTESANS LIFE',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'THE TWO BROTHERS',
#   'label': 'THE TWO BROTHERS',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'BUREAUCRACY',
#   'label': 'BUREAUCRACY',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'THE ILLUSTRIOUS GAUDISSART',
#   'label': 'THE ILLUSTRIOUS GAUDISSART',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#b97a7a',
#   'id': 'THE MAGIC SKIN',
#   'label': 'THE MAGIC SKIN',
#   'scene': 'ETUDES PHILOSOPHIQUES',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'A DISTINGUISHED PROVINCIAL AT PARIS',
#   'label': 'A DISTINGUISHED PROVINCIAL AT PARIS',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'THE FIRM OF NUCINGEN',
#   'label': 'THE FIRM OF NUCINGEN',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'BEATRIX',
#   'label': 'BEATRIX',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'RISE AND FALL OF CESAR BIROTTEAU',
#   'label': 'RISE AND FALL OF CESAR BIROTTEAU',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'THE MUSE OF THE DEPARTMENT',
#   'label': 'THE MUSE OF THE DEPARTMENT',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 60,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'A START IN LIFE',
#   'label': 'A START IN LIFE',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Comte Clément des Lupeaulx',
#   'label': 'Comte Clément des Lupeaulx',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Son of a wealthy father ennobled under Louis XV\\\\\\\\nPolitician who rises through social and administrative ranks, holds multiple high offices (Council of State, Finance Ministry, National Guard)\\\\\\\\nPowerful political intermediary for aristocratic interests\\\\\\\\nSocially prominent liberatine, usually features in high society scenes',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': ' #1a1a40',
#   'id': 'THE LESSER BOURGEOISIE',
#   'label': 'THE LESSER BOURGEOISIE',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'EVE AND DAVID',
#   'label': 'EVE AND DAVID',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'THE COLLECTION OF ANTIQUITIES',
#   'label': 'THE COLLECTION OF ANTIQUITIES',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'EUGENIE GRANDET',
#   'label': 'EUGENIE GRANDET',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#a5a58d',
#   'id': 'SONS OF THE SOIL',
#   'label': 'SONS OF THE SOIL',
#   'scene': 'SCENES DE LA VIE DE CAMPAGNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Comte Maxime de Trailles',
#   'label': 'Comte Maxime de Trailles',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Dandy, fashionable salon frequenter\\\\\\\\nNotorious for affairs with the rich and famous, notably Anastasie Restaud & Sarah Gobseck (whom he ruins)\\\\\\\\nProtege and close associate of Henri de Marsay \\\\\\\\nEventually ascends to a department deputy in spite of his poor reputation \\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': ' #1a1a40',
#   'id': 'UNCONSCIOUS COMEDIANS',
#   'label': 'UNCONSCIOUS COMEDIANS',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'THE MARRIAGE CONTRACT',
#   'label': 'THE MARRIAGE CONTRACT',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'GOBSECK',
#   'label': 'GOBSECK',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'THE SECRETS OF THE PRINCESSE DE CADIGNAN',
#   'label': 'THE SECRETS OF THE PRINCESSE DE CADIGNAN',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'THE COMMISSION IN LUNACY',
#   'label': 'THE COMMISSION IN LUNACY',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'COUSIN BETTY',
#   'label': 'COUSIN BETTY',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'FATHER GORIOT',
#   'label': 'FATHER GORIOT',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'A MAN OF BUSINESS',
#   'label': 'A MAN OF BUSINESS',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'PAZ',
#   'label': 'PAZ',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Duc de Rhétoré',
#   'label': 'Duc de Rhétoré',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': "Son and heir to the Duc and Duchesse de Chaulieu\\\\\\\\nDandy and society leader\\\\\\\\nLover of Madame du Bruel (the dancer Tullia) for many years\\\\\\\\nMarries the Duchesse d'Argaiolo",
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#9b8579',
#   'id': 'LETTERS OF TWO BRIDES',
#   'label': 'LETTERS OF TWO BRIDES',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'ALBERT SAVARUS',
#   'label': 'ALBERT SAVARUS',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'MODESTE MIGNON',
#   'label': 'MODESTE MIGNON',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Etienne Lousteau',
#   'label': 'Etienne Lousteau',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Parisian critic and journalist\\\\\\\\nClose associate of Nathan and Finot and trained Lucien du Rubempre in journalism\\\\\\\\nFormer lover of Madame Schontz/Madame du Ronceret',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Eugène de Rastignac',
#   'label': 'Eugène de Rastignac',
#   'scene': None,
#   'shape': 'dot',
#   'size': 70,
#   'type': 'character',
#   'title': 'Provincial minor noble turned Parisian dandy\\\\\\\\nDeftly moves between social groups \\\\\\\\nMost frequent recurring character of La Comedie Humaine who typefies the social climber\\\\\\\\nBegins as a poor law student and ascends to title of Comte de Rasignac over the course of the series\\\\\\\\nLongtime lover (and eventual son-in-law) of Delphine de Nucingen, ascends to wealth via Nucingen affairs',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#9b8579',
#   'id': 'THE BALL AT SCEAUX',
#   'label': 'THE BALL AT SCEAUX',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#b97a7a',
#   'id': 'MELMOTH RECONCILED',
#   'label': 'MELMOTH RECONCILED',
#   'scene': 'ETUDES PHILOSOPHIQUES',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#a5a58d',
#   'id': 'THE VILLAGE RECTOR',
#   'label': 'THE VILLAGE RECTOR',
#   'scene': 'SCENES DE LA VIE DE CAMPAGNE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#631d1d',
#   'id': 'AN HISTORICAL MYSTERY',
#   'label': 'AN HISTORICAL MYSTERY',
#   'scene': 'SCENES DE LA VIE POLITIQUE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'ANOTHER STUDY OF WOMAN',
#   'label': 'ANOTHER STUDY OF WOMAN',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 50,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'STUDY OF A WOMAN',
#   'label': 'STUDY OF A WOMAN',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Ferdinand du Tillet',
#   'label': 'Ferdinand du Tillet',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Commercial traveler and financier\\\\\\\\nConnects multiple characters and plots through finances, sometimes less savory dealings\\\\\\\\nClose associate of Nucingen and Claparon\\\\\\\\nLong-time lover of Madame Roguin',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#631d1d',
#   'id': 'THE BROTHERHOOD OF CONSOLATION',
#   'label': 'THE BROTHERHOOD OF CONSOLATION',
#   'scene': 'SCENES DE LA VIE POLITIQUE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'PIERRETTE',
#   'label': 'PIERRETTE',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'A WOMAN OF THIRTY',
#   'label': 'A WOMAN OF THIRTY',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Horace Bianchon',
#   'label': 'Horace Bianchon',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Doctor who studied under Desplein \\\\\\\\nSecond most frequent recurring character in La Comedie Humaine\\\\\\\\nAppears most often as a minor character, consulting on an illness\\\\\\\\nClose friend of Rastignac\\\\\\\\nBalzac is said to have called for Bianchon on his deathbed',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#9b8579',
#   'id': 'HONORINE',
#   'label': 'HONORINE',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'COUSIN PONS',
#   'label': 'COUSIN PONS',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'THE ATHEISTS MASS',
#   'label': 'THE ATHEISTS MASS',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'A SECOND HOME',
#   'label': 'A SECOND HOME',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Jean Francois du Bruel',
#   'label': 'Jean Francois du Bruel',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Wealthy civil servant and playwright\\\\\\\\nSometimes referred to by the penname \\\\\\\\\\\\\\"Cursy\\\\\\\\\\\\\\"\\\\\\\\nAscends to a peer of France and title of Comte\\\\\\\\nMarries the dancer Tullia, who is instrumental to his social rise',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Jean-Jacques Bixiou',
#   'label': 'Jean-Jacques Bixiou',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Famous caricature artist who rises to social prominence throughout the novels\\\\\\\\nObtains an administrative role through Duc de Maufrigneuse and Duc de Rhetore, earning financial stability\\\\\\\\nUsually features in company of journalists or artists\\\\\\\\nClose associate of Bridau, de Lora, and Schinner\\\\\\\\nKnown for his incisive wit ',
#   'gender': 'male',
#   'social_class': 'Artist'},
#  {'color': ' #1a1a40',
#   'id': 'GAUDISSART II',
#   'label': 'GAUDISSART II',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'THE PURSE',
#   'label': 'THE PURSE',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Madame Florine Nathan',
#   'label': 'Madame Florine Nathan',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Famous actress and social-climbing socialite\\\\\\\\nKept mistress to many of the rich and famous\\\\\\\\nLongtime lover and eventual wife of Raoul Nathan',
#   'gender': 'female',
#   'social_class': 'Artist'},
#  {'color': '#5a7684',
#   'id': 'Raoul Nathan',
#   'label': 'Raoul Nathan',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Poet, writer, and sometimes journalist\\\\\\\\nSocial-climbing son of a haberdasher \\\\\\\\nClose associate of Blondet, Finot, du Bruel \\\\\\\\nOften features as a social dilletante in high and low party scenes\\\\\\\\nLongtime lover and eventual husband of the actress Florine',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Émile Blondet',
#   'label': 'Émile Blondet',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Journalist\\\\\\\\nUsually features with other journalists\\\\\\\\nOften provides sharply ironic observations about contemporary France\\\\\\\\nMarries Madame Viginie de Montcornet, a notably rare happy ending',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Henri de Marsay',
#   'label': 'Henri de Marsay',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Dandy and lover of many of the rich and famous (incl. Lady Dudley, whose children are his)\\\\\\\\nIllegitimate son of Lord Dudley\\\\\\\\nMember of the Thirteen secret society \\\\\\\\nRepresents a dark undercurrent in the upper class, his sinister dealings with women are often mentioned',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': ' #1a1a40',
#   'id': 'THE DUCHESSE OF LANGEAIS',
#   'label': 'THE DUCHESSE OF LANGEAIS',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'THE GIRL WITH THE GOLDEN EYES',
#   'label': 'THE GIRL WITH THE GOLDEN EYES',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': ' #1a1a40',
#   'id': 'THE THIRTEEN',
#   'label': 'THE THIRTEEN',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#e3b564',
#   'id': 'THE LILY OF THE VALLEY',
#   'label': 'THE LILY OF THE VALLEY',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 40,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Lady Arabella Dudley',
#   'label': 'Lady Arabella Dudley',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'English aristocrat of searing wit notorious for her affairs with the rich and famous\\\\\\\\nEstranged wife of Lord Dudley\\\\\\\\nFormer lover of Felix de Vandenesse, becomes an enemy to him and later his wife\\\\\\\\nHenri de Marsay is the father of her children',
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Lord Dudley',
#   'label': 'Lord Dudley',
#   'scene': None,
#   'shape': 'dot',
#   'size': 15,
#   'type': 'character',
#   'title': 'Powerful English aristocrat and statesman \\\\\\\\nIllegitimate father of Henri de Marsay\\\\\\\\nHusband of Lady Dudley\\\\\\\\nKnown for his immorality and numerous mistresses\\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Mademoiselle des Touches',
#   'label': 'Mademoiselle des Touches',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Famous writer known as \\\\\\\\\\\\\\"Camille Maupin\\\\\\\\\\\\\\"\\\\\\\\nSociety host often surrounded by artists\\\\\\\\nWealthy patron of the arts from a wealthy aristocratic family \\\\\\\\nHeavily inspired by George Sand',
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Francois-Claude-Marie Godeschal',
#   'label': 'Francois-Claude-Marie Godeschal',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Begins as a law clerk, becomes a succesful lawyer\\\\\\\\nBrother of Marie (the dancer Mariette) \\\\\\\\nOften features in legal scenes involving petitions and contracts',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#9b8579',
#   'id': 'COLONEL CHABERT',
#   'label': 'COLONEL CHABERT',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Charles Claparon',
#   'label': 'Charles Claparon',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Commercial traveler and banker\\\\\\\\nClose associate of Ferdinand du Tillet and Nucingen, involved in less savory dealings\\\\\\\\nEventually becomes bankrupt and emigrates',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Joseph Bridau',
#   'label': 'Joseph Bridau',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': "Famous painter who rises to social prominence throughout the novels\\\\\\\\nUsually features in company of the Parisian artists' circle\\\\\\\\nRaised as the black sheep of a military family\\\\\\\\nOften mentioned in the context of his work (paintings, decorating homes)\\\\\\\\nClose associate of Bixiou, de Lora, and Schinner",
#   'gender': 'male',
#   'social_class': 'Artist'},
#  {'color': '#9b8579',
#   'id': 'PIERRE GRASSOU',
#   'label': 'PIERRE GRASSOU',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Baron de Nucingen',
#   'label': 'Baron de Nucingen',
#   'scene': None,
#   'shape': 'dot',
#   'size': 40,
#   'type': 'character',
#   'title': 'Wealthy banker and financier, connects multiple characters and plots via financing\\\\\\\\nFinancial bougeoisie by social role; Alsatian by birth, first rises to wealth and prominence during the Restoration \\\\\\\\nHusband of Delphine \\\\\\\\nLover of Esther van Gobseck, with whom he is passionately obsessed\\\\\\\\nClose associate of du Tillet and of Rastignac (who eventually becomes his son-in-law)\\\\\\\\nBalzac uses his name as a stand-in for wealth (a Nucingen) ',
#   'gender': 'male',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': ' #1a1a40',
#   'id': 'SARRASINE',
#   'label': 'SARRASINE',
#   'scene': 'SCENES DE LA VIE PARISIENNE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Martial de La Roche-Hugon',
#   'label': 'Martial de La Roche-Hugon',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Influential politician, ascends to social prominence via rising through administrative roles\\\\\\\\nServed Empire, Bourbons, and July Monarchy\\\\\\\\nEventually becomes brother-in-law to Rastignac, who arranges his marriage with one of his sisters',
#   'gender': 'male',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': '#9b8579',
#   'id': 'DOMESTIC PEACE',
#   'label': 'DOMESTIC PEACE',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Comte de Granville',
#   'label': 'Comte de Granville',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Head of a wealthy aristocratic family\\\\\\\\nMagistrate with important judicial & administrative roles\\\\\\\\nUnhappily married to Angelique de Granville \\\\\\\\nBecomes father-in-law of Felix de Vandenesse and of Ferdinand du Tillet',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Jacques Collin',
#   'label': 'Jacques Collin',
#   'scene': None,
#   'shape': 'dot',
#   'size': 50,
#   'type': 'character',
#   'title': 'Criminal mastermind on the run from the law\\\\\\\\nHis expoits eventually earn him a role as police chief\\\\\\\\nPatron of Lucien de Rubempre\\\\\\\\nNumerous false identities and aliases: Vautrin, Abbe Carlos Herrera, Trompe-la-Morte',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Baron de Canalis',
#   'label': 'Baron de Canalis',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Famous poet who rises to social prominence \\\\\\\\nAscends social ranks & administrative roles aided by his affair with the Duchesse de Chaulieu\\\\\\\\nOften features in high society scenes \\\\\\\\nOften mentioned in the context of his poetry and songs\\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': '#e3b564',
#   'id': 'TWO POETS',
#   'label': 'TWO POETS',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 30,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Comte Félix de Vandenesse',
#   'label': 'Comte Félix de Vandenesse',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': "Royal secretary\\\\\\\\nDandy, fashionable salon frequenter\\\\\\\\nConnected to much of the featured nobility through family or marriage\\\\\\\\nFormer lover of Lady Dudley, Natalie de Manerville, Madame de Mortsauf \\\\\\\\nMarries Mlle. Marie-Angelique de Granville\\\\\\\\nHis character is partially autobiographical, pulling from Balzac's own unhappy childhood and early romantic experiences",
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Duchesse de Maufrigneuse',
#   'label': 'Duchesse de Maufrigneuse',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': "Society leader considered the most powerful of the Parisian salon heads\\\\\\\\nNotorious for affairs with many of the rich and famous\\\\\\\\nAscends to the title of Princesse de Cadignan upon her father-in-law's death (but abandoned by her husband)\\\\\\\\nLongtime enemy, later close friend of the Marquise d'Espard",
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#9b8579',
#   'id': 'MADAME FIRMIANI',
#   'label': 'MADAME FIRMIANI',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Desplein',
#   'label': 'Desplein',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Famous doctor\\\\\\\\nTeacher of Bianchon\\\\\\\\nAppears most often as a minor character, a consulting physician in illness scenes',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Duc de Navarreins',
#   'label': 'Duc de Navarreins',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': "Head of old, wealthy aristocratic family\\\\\\\\nPowerful society figure with ties to many of the featured nobility through. patronage, family, or marriage\\\\\\\\nFather of the Duchesse de Langeais and cousin to the Marquise d'Espard\\\\\\\\nPatron to du Bruel ",
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#e3b564',
#   'id': 'AN OLD MAID',
#   'label': 'AN OLD MAID',
#   'scene': 'SCENES DE LA VIE PROVINCE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'General de Montriveau',
#   'label': 'General de Montriveau',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Born the son of a general and chevalier\\\\\\\\nOrphaned young and was patronized by Napoleon\\\\\\\\nCampaigned through Egypt and Africa, where he was held captive before his escape and return to Paris\\\\\\\\nRises through military ranks, eventually ascending to general \\\\\\\\nMember of the Thirteen secret society\\\\\\\\nLover of the Duchesse de Langeais',
#   'gender': 'male',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': '#5a7684',
#   'id': 'Comtesse de Serizy',
#   'label': 'Comtesse de Serizy',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'High society salon leader \\\\\\\\nBorn \\\\\\\\\\\\\\"Leontine de Ronquerolles\\\\\\\\\\\\\\", from a wealthy family and sister of the Marquis de Ronquerolles \\\\\\\\nWife of the Comte de Serizy, unhappily married and often unfaithful\\\\\\\\nFormer lover of Lucien du Rubempre, a notably passionate affair\\\\\\\\n',
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Marquis de Ronquerolles',
#   'label': 'Marquis de Ronquerolles',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Head of old aristocratic family \\\\\\\\nDiplomat, later deputy of a department in Bourgogne\\\\\\\\nOften features in high society scenes\\\\\\\\nBrother of Madame de Serizy\\\\\\\\nMember of the Thirteen secret society',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Duc de Grandlieu',
#   'label': 'Duc de Grandlieu',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Head of old, wealthy aristocratic family\\\\\\\\nPowerful society figure with pull in government and at court\\\\\\\\nMarried to an Ajuda, connecting him to Portuguese aristocracy\\\\\\\\nFather to five daughters',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Baronne Delphine de Nucingen',
#   'label': 'Baronne Delphine de Nucingen',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': 'Social-climbing daughter of old Goriot, a wealthy vermicelli manufacturer\\\\\\\\nFinancial bougeoisie by social role; becomes a society salon leader over time\\\\\\\\nWife of Nucingen\\\\\\\\nFormer lover of Henri de Marsay\\\\\\\\nLongtime lover (and later mother-in-law) of Rastignac ',
#   'gender': 'female',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': '#5a7684',
#   'id': 'Stidmann',
#   'label': 'Stidmann',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Famous sculptor\\\\\\\\nGenerally mentioned in the context of his work (decorative pieces, monuments) \\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'Artist'},
#  {'color': '#5a7684',
#   'id': 'Virginie Blondet',
#   'label': 'Virginie Blondet',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Born provincial nobility Virginie de Troisville, marries Marechal de Montcornet \\\\\\\\nSociety host of artists and intellectuals\\\\\\\\nMarries Emile Blondet upon the death of Montcornet, a notable happy ending',
#   'gender': 'female',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Leon de Lora',
#   'label': 'Leon de Lora',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Famous artist\\\\\\\\nUsually features in company of Bridau or other artists\\\\\\\\nKnown as \\\\\\\\\\\\\\"Mistigris\\\\\\\\\\\\\\" and often mentioned in context of his works (especially landscapes)',
#   'gender': 'male',
#   'social_class': 'Artist'},
#  {'color': '#5a7684',
#   'id': 'Lucien de Rubempré',
#   'label': 'Lucien de Rubempré',
#   'scene': None,
#   'shape': 'dot',
#   'size': 100,
#   'type': 'character',
#   'title': "Provincial celebrity turned Parisian social-climber\\\\\\\\nBorn to a tradesman father and aristocratic mother, seeks to re-establish his family's noble name and title\\\\\\\\nBegins as a poet, becomes a journalist\\\\\\\\nLover of many of the rich and famous, including Coralie and Esther Gobseck (both of whom he ruins)\\\\\\\\nAscends to wealth as accomplice and would-be protege of Jacques Collin ",
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Félicien Vernou',
#   'label': 'Félicien Vernou',
#   'scene': None,
#   'shape': 'dot',
#   'size': 20,
#   'type': 'character',
#   'title': 'Journalist\\\\\\\\nOften features with other journalists\\\\\\\\nNotable for his bitterness and unhappy marriage',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Marechal de Montcornet',
#   'label': 'Marechal de Montcornet',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Military general, ascends to social prominence via earned wealth and rank \\\\\\\\nNapoleonic officer turned marshal, count, and army commander under the July Monarchy\\\\\\\\nBecomes a wealthy landowner but struggles to fit in with the aristocracy due to his temperament and character\\\\\\\\nFirst husband of Virginie Blondet (Mme. de Montcornet) and has ties to the artistic circles through her\\\\\\\\n\\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'State/Imperial Nobility'},
#  {'color': '#5a7684',
#   'id': 'Claude Vignon',
#   'label': 'Claude Vignon',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Newspaper critic famed for his wit and insight\\\\\\\\nOften features with other journalists \\\\\\\\nLong-time lover of Mademoiselle des Touches\\\\\\\\nMentor of the courtesan La Schontz (who becomes Mme. du Ronceret)',
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Hippolyte Schinner',
#   'label': 'Hippolyte Schinner',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Famous artist who rises to social prominences throughout the novels\\\\\\\\nOften mentioned in context of his work (paintings, decorating homes)\\\\\\\\nClose associate of Bridau, de Lora, and Bixiou',
#   'gender': 'male',
#   'social_class': 'Artist'},
#  {'color': '#5a7684',
#   'id': 'Madame Josephine du Ronceret',
#   'label': 'Madame Josephine du Ronceret',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Formerly \\\\\\\\\\\\\\"Madame Schontz,\\\\\\\\\\\\\\" a courtesan famed for her intelligence and wit\\\\\\\\nFormer mistress of Lousteau, then Stidmann & often features with artists and critics\\\\\\\\nMarries Fabien du Ronceret, a judicial official\\\\\\\\n',
#   'gender': 'female',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Comte de Serizy',
#   'label': 'Comte de Serizy',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': 'Powerful society leader from an aristocratic family\\\\\\\\nBecame a count under the Empire and succeeded to several high government posts\\\\\\\\nHusband of Madame de Serizy, unhappily married\\\\\\\\n',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Felix Gaudissart',
#   'label': 'Felix Gaudissart',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': "Commercial traveler, formerly in the hat trade in the employ of Finot's father\\\\\\\\nInvolved in various conspiracies and commercial schemes\\\\\\\\nTheatre owner",
#   'gender': 'male',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#5a7684',
#   'id': 'Baronne Marie-Louise du Châtelet',
#   'label': 'Baronne Marie-Louise du Châtelet',
#   'scene': None,
#   'shape': 'dot',
#   'size': 30,
#   'type': 'character',
#   'title': "Social leader of Angouleme from provincial minor nobility\\\\\\\\nBecomes Baronne du Chatelet on her second marriage to Baron Sixte du Chatelet\\\\\\\\nFormer lover of Lucien de Rubempre\\\\\\\\nCousin of Marquise d'Espard",
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Duc de Lenoncourt',
#   'label': 'Duc de Lenoncourt',
#   'scene': None,
#   'shape': 'dot',
#   'size': 15,
#   'type': 'character',
#   'title': 'Head of old, wealthy aristocratic family\\\\\\\\nConnected to many of the featured nobility through family or marriage\\\\\\\\nPowerful society figure with long-standing ties to the monarchy\\\\\\\\nFather of Madame de Mortsauf ',
#   'gender': 'male',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#5a7684',
#   'id': 'Madame Roguin',
#   'label': 'Madame Roguin',
#   'scene': None,
#   'shape': 'dot',
#   'size': 15,
#   'type': 'character',
#   'title': 'Wealthy provinical bourgeouisie \\\\\\\\nWife of Roguin and daughter of a banker\\\\\\\\nLong-time mistress of Ferdinand du Tillet',
#   'gender': 'female',
#   'social_class': 'Bourgeoisie'},
#  {'color': '#9b8579',
#   'id': 'VENDETTA',
#   'label': 'VENDETTA',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#9b8579',
#   'id': 'AT THE SIGN OF THE CAT AND RACKET',
#   'label': 'AT THE SIGN OF THE CAT AND RACKET',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None},
#  {'color': '#5a7684',
#   'id': 'Vicomtesse de Beauséant',
#   'label': 'Vicomtesse de Beauséant',
#   'scene': None,
#   'shape': 'dot',
#   'size': 25,
#   'type': 'character',
#   'title': "Cousin of Rastignac\\\\\\\\nEventually Comtesse, then Marquise de Beauseant\\\\\\\\nAbsconds from la mode brillant following the end of a love affair with the Marquis d'Ajuda-Pinto",
#   'gender': 'female',
#   'social_class': 'Old Aristocracy'},
#  {'color': '#9b8579',
#   'id': 'THE DESERTED WOMAN',
#   'label': 'THE DESERTED WOMAN',
#   'scene': 'SCENES DE LA VIE PRIVEE',
#   'shape': 'square',
#   'size': 20,
#   'type': 'novel',
#   'title': None,
#   'gender': None,
#   'social_class': None}]
