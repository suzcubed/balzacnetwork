# %% [markdown]
# ## Import data & add new metadata

# %%
from pathlib import Path
home = Path.home()
file_dir = home / "balzac_project"/ "balzac_project" / "data"

# %%
import pandas as pd
import os
from collections import Counter

os.chdir(file_dir)

nodes_df = pd.read_csv('nodes_vs_export.csv')
nodes = [{'data': row.to_dict()} for _, row in nodes_df.iterrows()]
net_df = pd.read_csv('character_frequencies.csv')
metadata_df = pd.read_csv('character_metadata.csv')

# %%
# merge new metadata into nodes_df

metadata_df = metadata_df.rename(columns={"Character": "id"})
nodes_df = nodes_df.reset_index()
metadata_df = metadata_df.reset_index()
nodes_df = nodes_df.merge(metadata_df, on="id", how="left")

# %%
nodes_df.drop(columns=['Name Variants', 'index_y', 'Major Appearances', 'Minor Appearances', 'index_x'], inplace=True)

# %%
nodes_df
# Out:
#                                     id                              label  \
# 0                        Andoche Finot                      Andoche Finot
# 1                  A PRINCE OF BOHEMIA                A PRINCE OF BOHEMIA
# 2                  THE DEPUTY OF ARCIS                THE DEPUTY OF ARCIS
# 3                    A DAUGHTER OF EVE                  A DAUGHTER OF EVE
# 4                               URSULA                             URSULA
# ..                                 ...                                ...
# 105                      Madame Roguin                      Madame Roguin
# 106                           VENDETTA                           VENDETTA
# 107  AT THE SIGN OF THE CAT AND RACKET  AT THE SIGN OF THE CAT AND RACKET
# 108            Vicomtesse de Beauséant            Vicomtesse de Beauséant
# 109                 THE DESERTED WOMAN                 THE DESERTED WOMAN
#
#           type       color   shape  size                        scene  Gender  \
# 0    character     skyblue     dot    25                          NaN    male
# 1        novel     #FF6F61  square    40  SCENES DE LA VIE PARISIENNE     NaN
# 2        novel   goldenrod  square    50   SCENES DE LA VIE POLITIQUE     NaN
# 3        novel        blue  square    50      SCENES DE LA VIE PRIVEE     NaN
# 4        novel  sandybrown  square    40    SCENES DE LA VIE PROVINCE     NaN
# ..         ...         ...     ...   ...                          ...     ...
# 105  character     skyblue     dot    10                          NaN  female
# 106      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
# 107      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
# 108  character     skyblue     dot    20                          NaN  female
# 109      novel        blue  square    10      SCENES DE LA VIE PRIVEE     NaN
#
#         Social Class                              Character Description
# 0       Bourgeoisie   Newspaper editor and businessman\nSon of a hat...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# ..               ...                                                ...
# 105     Bourgeoisie   Wealthy provinical bourgeouisie \nWife of Rogu...
# 106              NaN                                                NaN
# 107              NaN                                                NaN
# 108  Old Aristocracy  Cousin of Rastignac\nEventually Comtesse, then...
# 109              NaN                                                NaN
#
# [110 rows x 10 columns]

# %% [markdown]
# ## Update graph HTML with beautiful soup

# %%
graph_dir = home / "balzac_project" / "balzac_project"
os.chdir(graph_dir)

# %%
from bs4 import BeautifulSoup
# open HTML file
with open("balzac_character_network_with_filters.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

script_tag = None
for s in soup.find_all("script"):
    if "nodes = new vis.DataSet" in s.text:
        script_tag = s
        break

script_text = script_tag.string

# %%
nodes_df['Social Class'] = nodes_df['Social Class'].str.strip()
nodes_df['Gender'] = nodes_df['Gender'].str.strip()

# %%
import regex as re
import json

pattern = r"new vis\.DataSet\(\s*(\[\{.*?\}\])\s*\)"
match = re.search(pattern, script_text, re.DOTALL)
if match:
    nodes_json_str = match.group(1)
    # Replace NaN/undefined with null
    nodes_json_str = nodes_json_str.replace("NaN", "null").replace("undefined", "null")
    # Now load JSON
    nodes_list = json.loads(nodes_json_str)
else:
    raise ValueError("Could not find vis.DataSet array")




for node in nodes_list:
    node_id = node['id']
    if node_id in nodes_df.index:
        node['gender'] = nodes_df.at[node_id, 'Gender']
        node['social_class'] = nodes_df.at[node_id, 'Social Class']
    else:
        node['gender'] = None
        node['social_class'] = None

# %%
nodes_df['gender'] = nodes_df['gender'].where(nodes_df['gender'].notna(), None)
nodes_df['social_class'] = nodes_df['social_class'].where(nodes_df['social_class'].notna(), None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 nodes_df['gender'] = nodes_df['gender'].where(nodes_df['gender'].notna(), None)
#       2 nodes_df['social_class'] = nodes_df['social_class'].where(nodes_df['social_class'].notna(), None)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'gender'
